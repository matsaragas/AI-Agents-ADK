# %%
from dotenv import load_dotenv
import os

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
load_dotenv()  # automatically looks for .env in the current directory
google_api_key = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Section 2: Why Multi-Agent Systems? + Your First Multi-Agent¶
#
# The Problem: The "Do-It-All" Agent
#
# Single agents can do a lot. But what happens when the task gets complex? A single "monolithic" agent that tries to do research, writing, editing, and fact-checking all at once becomes a problem. Its instruction prompt gets long and confusing. It's hard to debug (which part failed?), difficult to maintain, and often produces unreliable results.
#
# The Solution: A Team of Specialists
#
# Instead of one "do-it-all" agent, we can build a multi-agent system. This is a team of simple, specialized agents that collaborate, just like a real-world team. Each agent has one clear job (e.g., one agent only does research, another only writes). This makes them easier to build, easier to test, and much more powerful and reliable when working together.

# %% [markdown]
# #### 2.1 Example: Research & Summarization System¶
# Let's build a system with two specialized agents:
#
# Research Agent - Searches for information using Google Search
# Summarizer Agent - Creates concise summaries from research findings

# %%
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

# %%
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

# %% [markdown]
# ##### Then we bring the agents together under a root agent, or coordinator:

# %%
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The latest advancements in quantum computing are set to significantly enhance AI capabilities by improving data processing, model optimization, and problem-solving. Key developments include progress in Quantum Machine Learning (QML), with research into quantum neural networks and other models, showing early advantages over classical systems despite current challenges. AI itself is now aiding in the creation of quantum algorithms. Hardware and materials are also advancing, paving the way for more robust quantum computers. While widespread adoption is still developing, early applications in optimization are emerging. By 2030, quantum computing is projected to revolutionize AI, enabling it to tackle highly complex problems and leading to the adoption of hybrid quantum-classical approaches across various industries.

# %% [markdown]
# ### Section 3: Sequential Workflows - The Assembly Line
#
# The Problem: Unpredictable Order
#
# The previous multi-agent system worked, but it relied on a detailed instruction prompt to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.

# %% [markdown]
# The Solution: A Fixed Pipeline
#
# When you need tasks to happen in a guaranteed, specific order, you can use a SequentialAgent. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# Use Sequential when: Order matters, you need a linear pipeline, or each step builds on the previous one.

# %% [markdown]
# #### 3.1 Example: Blog Post Creation with Sequential Agents¶
# Let's build a system with three specialized agents:
#
# Outline Agent - Creates a blog outline for a given topic
# Writer Agent - Writes a blog post
# Editor Agent - Edits a blog post draft for clarity and structure

# %%
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

# %%
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

# %%
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

# %% [markdown]
# Then we bring the agents together under a sequential agent, which runs the agents in the order that they are listed:

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)

# %% [markdown]
# #### Section 4: Parallel Workflows - Independent Researchers

# %% [markdown]
# The Problem: The Bottleneck
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are not dependent on each other? For example, researching three different topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# The Solution: Concurrent Execution
#
# When you have independent tasks, you can run them all at the same time using a ParallelAgent. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# Use Parallel when: Tasks are independent, speed matters, and you can execute concurrently.

# %% [markdown]
# #### 4.1 Example: Parallel Multi-Topic Research¶
# Let's build a system with four agents:
#
# Tech Researcher - Researches AI/ML news and trends
# Health Researcher - Researches recent medical news and trends
# Finance Researcher - Researches finance and fintech news and trends
# Aggregator Agent - Combines all research findings into a single summary

# %%
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

# %%
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

# %%
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

# %%
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

# %%
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > ## Daily Executive Briefing: December 15, 2025
#
# **Technology:** The AI talent war is intensifying, with companies like OpenAI eliminating vesting cliffs to retain engineers amidst fierce competition and high compensation packages. This signals a shift towards prioritizing immediate retention over traditional long-term incentives. CEOs plan to increase AI spending in 2026 despite mixed returns, indicating a strategic bet on future AI-driven growth.
#
# **Health:** Africa CDC is holding a briefing on health emergencies, focusing on preparedness and continental security. A new initiative to modernize health supply chains using drone logistics has been launched in Africa, aiming to improve access to medical products. Globally, WHO emphasizes the importance of protecting healthcare facilities and warns of potential increases in childhood mortality due to steep cuts in development assistance.
#
# **Finance:** Diverging global interest rates and monetary policies require asset allocators to adopt more active strategies. US tech companies are seeing a surge in credit default swaps, indicating increased investor concern over debt levels amidst the AI investment boom. Despite market expensiveness and AI-driven excesses, macroeconomic conditions do not yet justify a significant withdrawal from risk.
#
# ---
#
# ## Fintech Trends:
#
# **1. Embedded Finance:**
# *   **Market Implications:** Financial services are increasingly integrated into non-financial platforms (e.g., e-commerce, SaaS). This broadens access to financial products and creates new revenue streams for platform providers.
# *   **Future Outlook:** Expect deeper integration, with more personalized financial offerings directly within user workflows, potentially disintermediating traditional banks for certain services.
#
# **2. AI and Machine Learning in Financial Services:**
# *   **Market Implications:** AI is revolutionizing fraud detection, risk assessment, personalized customer service (chatbots), and algorithmic trading. This leads to improved efficiency, reduced costs, and enhanced customer experiences.
# *   **Future Outlook:** AI will become more sophisticated, driving hyper-personalization, predictive analytics for market movements, and automated compliance, further transforming operational models.
#
# **3. Decentralized Finance (DeFi) Evolution:**
# *   **Market Implications:** While still nascent, DeFi offers alternative financial systems built on blockchain. It promises greater transparency, accessibility, and lower transaction costs for services like lending, borrowing, and trading.
# *   **Future Outlook:** DeFi is likely to mature, with increased regulatory clarity, improved user interfaces, and interoperability with traditional finance, potentially offering viable alternatives for specific financial needs.
# HealthResearcher > Here's a concise executive briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** Gene therapy shows immense promise for treating genetic diseases and cancer. Non-hormonal treatments for hot flashes are now available, and AI is enhancing heart health diagnostics. Regenerative medicine is advancing with heart tissue patches and lab-grown ureter tissue.
#
# **Tech:** Edge AI and 5G are integrating, allowing devices to process information locally for increased speed and privacy. Autonomous and collaborative robotics are scaling across industries. Innovations in battery technology promise ultra-fast charging.
#
# **Finance:** Blockchain is transforming finance with applications in bond issuance and decentralized finance, increasing transparency and efficiency. AI and machine learning are redefining risk assessment and user experience. Ripple's banking approval and institutional adoption of XRP highlight a bridging of traditional and digital finance.
#
# **Timelines:** Many of these advancements are already in practical application or are expected to see significant scaling within the next 1-3 years.
# TechResearcher > **AI/ML Trends: The Latest Developments and Their Impact**
#
# Artificial Intelligence (AI) and Machine Learning (ML) continue to drive rapid innovation across industries. Here are three key developments:
#
# 1.  **Generative AI Proliferation:** Generative AI tools are surging, enabling content creation, design, and workflow streamlining. Companies like **OpenAI**, **Google (Alphabet)**, and **Microsoft** are at the forefront, with models like ChatGPT and Gemini showcasing advanced conversational and creative capabilities. The impact includes significant ROI, particularly in financial services, and enhanced productivity, with employees saving considerable time on daily tasks.
#
# 2.  **Multimodal AI Integration:** AI systems now adeptly process diverse data types, including text, images, video, and audio. This facilitates more intuitive applications. Major players like **Google**, **Amazon**, and **Microsoft** are developing these capabilities. The impact is more versatile AI applications and improved user experiences, enabling natural interactions that go beyond text.
#
# 3.  **Agentic AI and Enhanced Automation:** AI-powered agents are gaining autonomy, capable of handling complex tasks and simplifying daily operations. Companies like **H2O.ai** are pioneering "Agentic AI." This trend is expected to revolutionize work by automating processes, improving decision-making, and leading to greater efficiency across sectors such as healthcare, finance, and manufacturing.
#
# These advancements, driven by tech giants like **NVIDIA**, **Apple**, and **Amazon**, are transforming industries by boosting productivity, enabling new business models, and reshaping how we interact with technology.
# AggregatorAgent > ## Executive Summary: Converging Innovations in Tech, Health, and Finance
#
# The landscape of innovation is characterized by the accelerating integration of Artificial Intelligence (AI) across all sectors, driving significant advancements and demanding strategic adaptation.
#
# **Key Themes:**
#
# *   **AI as a Transformative Force:** Generative, multimodal, and agentic AI are revolutionizing content creation, user experiences, and automation. This is evident in financial services through enhanced risk assessment and customer service, and in healthcare via improved diagnostics and personalized treatments. The intense competition for AI talent, highlighted by companies like OpenAI, underscores its critical importance and the significant investment planned for its future development.
# *   **Bridging Traditional and Digital:** Finance is seeing a convergence of traditional and digital models, with blockchain enabling new forms of bond issuance and decentralized finance (DeFi) offering alternative systems. Similarly, advancements in edge AI and 5G are enhancing the capabilities of devices, while innovations in battery technology promise faster charging.
# *   **Health Advancements Driven by Technology:** Gene therapy, regenerative medicine, and AI-powered diagnostics are paving the way for new treatments and improved health outcomes. Concurrently, the modernization of health supply chains, particularly in Africa through drone logistics, addresses critical access issues.
#
# **Key Takeaways:**
#
# The pervasive influence of AI is creating a more efficient, personalized, and automated future. Strategic investment in AI, alongside the maturation of technologies like blockchain and edge computing, will be crucial for growth. While significant opportunities exist, attention must also be paid to global health security, equitable access to medical products, and managing the financial risks associated with rapid technological investment. Many of these advancements are poised for significant scaling within the next 1-3 years.

# %% [markdown]
# ### Section 5: Loop Workflows - The Refinement Cycle
#
# The Problem: One-Shot Quality
#
# All the workflows we've seen so far run from start to finish. The SequentialAgent and ParallelAgent produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# The Problem: One-Shot Quality
#
# All the workflows we've seen so far run from start to finish. The SequentialAgent and ParallelAgent produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.

# %% [markdown]
# #### 5.1 Example: Iterative Story Refinement¶
# Let's build a system with two agents:
#
# Writer Agent - Writes a draft of a short story
# Critic Agent - Reviews and critiques the short story to suggest improvements

# %%
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

# %%
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

# %%
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

# %%
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

# %% [markdown]
# Then we bring the agents together under a loop agent, which is itself nested inside of a sequential agent.
#
# This design ensures that the system first produces an initial story draft, then the refinement loop runs up to the specified number of max_iterations:

# %%
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# FinanceResearcher > Here are three key fintech trends:
#
# **1. AI-Driven Transformation:**
# Artificial Intelligence is revolutionizing finance by enabling hyper-personalization, automating processes, and enhancing fraud detection. Market implications include increased operational efficiency, improved customer experiences, and more accurate risk management. The future outlook points to AI becoming essential for fintech survival, driving innovation in services and personalized financial advice.
#
# **2. Embedded Finance:**
# This trend involves integrating financial services directly into non-financial platforms, offering seamless experiences. Market implications include new revenue streams for businesses, enhanced customer loyalty, and a disintermediation of traditional financial institutions. The future sees embedded finance becoming an industry standard, with significant market growth projected and a continued demand for integrated financial experiences.
#
# **3. Decentralized Finance (DeFi):**
# DeFi leverages blockchain to offer financial services without intermediaries, promoting accessibility and lower costs. Market implications include challenging traditional banking, increasing financial inclusion, and attracting institutional investment. The future outlook suggests DeFi will become increasingly integrated with traditional finance, with growth driven by tokenization and regulatory clarity.
# TechResearcher > Sure, here is a short story about a lighthouse keeper who discovers a mysterious, glowing map:
#
# The salt spray was a familiar kiss on Elias Thorne's weathered face as he climbed the winding stairs of the Blackrock Point lighthouse. For twenty years, the rhythmic sweep of the beam and the mournful cry of the foghorn had been his only companions. But tonight, the storm raged with unusual fury, and a strange luminescence flickered in the disused storage room.
#
# Curiosity, a rare visitor in his solitary life, tugged him towards it. Behind a pile of barnacle-encrusted fishing nets, he found an old sea chest, its wood bleached and warped. Inside, nestled amongst faded charts and a sailor's tarnished spyglass, lay a map. It wasn't parchment or paper, but something akin to hammered moonlight, softly glowing with an inner, ethereal light. Intricate symbols, unlike any he'd ever seen, pulsed across its surface, hinting at oceans unknown and shores uncharted.
#
# As Elias traced a shimmering line with his calloused finger, a faint hum filled the air, and the map's glow intensified, casting dancing patterns on the stone walls. He felt a pull, a silent invitation to a world beyond the horizon, a promise whispered by the sea itself. The lighthouse, his steadfast sentinel, now seemed to guard not just the treacherous coast, but the gateway to an extraordinary mystery. He knew, with a certainty that settled deep in his bones, that his quiet life on Blackrock Point was about to change forever.**Key AI/ML Trends:**
#
# 1.  **Generative AI Proliferation:** Generative AI is rapidly advancing, with companies like OpenAI, Google, and Microsoft leading in developing sophisticated models for content creation, coding, and more. This trend is democratizing AI capabilities and is expected to transform industries by automating creative tasks and accelerating production.
# 2.  **AI in Healthcare and Drug Discovery:** AI is revolutionizing healthcare by enabling early disease detection, personalized treatment plans, and accelerating drug discovery. Companies like Google Health, IBM Watson Health, and NVIDIA are at the forefront. In drug discovery, AI analyzes vast biological data to identify potential drug candidates, significantly reducing development time and costs.
# 3.  **AI for Climate Change Mitigation and Adaptation:** AI is becoming crucial in combating climate change by improving climate modeling, optimizing renewable energy, and monitoring environmental changes. Companies such as Google, Microsoft, and Amazon are leveraging AI for these efforts, while specialized firms like Veritree and Treefera are developing AI-driven solutions for nature restoration and supply chain transparency.
#
# **Main Companies Involved:**
# *   **Generative AI:** OpenAI, Google, Microsoft, NVIDIA.
# *   **Healthcare/Drug Discovery:** Google Health, IBM Watson Health, Microsoft, NVIDIA, Tempus, Recursion.
# *   **Climate Change:** Google, Microsoft, Amazon, Veritree, Treefera, Planet Labs.
#
# **Potential Impact:**
# These trends signal a significant shift towards more intelligent automation, personalized solutions in healthcare, and a data-driven approach to environmental sustainability. The impact ranges from increased efficiency and innovation across sectors to addressing critical global challenges like climate change and disease.
